# %% [markdown]
# # Importing the Data

# %%
import pandas as pd 
covid = pd.read_csv('/kaggle/input/covid-world-vaccination-progress/country_vaccinations.csv')

#reviewing the first 5 rows of the data
covid.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# # Exploring General Functions

# %% [markdown]
# .melt(): unpivot a DF from wide to long format

# %%
# name = country, value = people vaccinated
covid.melt(id_vars=['country'], value_vars=['people_vaccinated'])
# Out:
#        country           variable    value
# 0      Albania  people_vaccinated      0.0
# 1      Albania  people_vaccinated      NaN
# 2      Albania  people_vaccinated    128.0
# 3      Albania  people_vaccinated    188.0
# 4      Albania  people_vaccinated    266.0
# ...        ...                ...      ...
# 5231  Zimbabwe  people_vaccinated  21456.0
# 5232  Zimbabwe  people_vaccinated  25077.0
# 5233  Zimbabwe  people_vaccinated  27970.0
# 5234  Zimbabwe  people_vaccinated  30658.0
# 5235  Zimbabwe  people_vaccinated  31325.0
#
# [5236 rows x 3 columns]

# %%
# eg. unpivot multiple columns (date and people_vaccinated) as well as change column names
covid.melt(id_vars=['country'], value_vars=['date','people_vaccinated'], var_name='New_Var', value_name='New_Value')
# Out:
#         country            New_Var   New_Value
# 0       Albania               date  2021-01-10
# 1       Albania               date  2021-01-11
# 2       Albania               date  2021-01-12
# 3       Albania               date  2021-01-13
# 4       Albania               date  2021-01-14
# ...         ...                ...         ...
# 10467  Zimbabwe  people_vaccinated     21456.0
# 10468  Zimbabwe  people_vaccinated     25077.0
# 10469  Zimbabwe  people_vaccinated     27970.0
# 10470  Zimbabwe  people_vaccinated     30658.0
# 10471  Zimbabwe  people_vaccinated     31325.0
#
# [10472 rows x 3 columns]

# %% [markdown]
# .pivot(): produces pivot tables based on 3 columns of the DF

# %%
covid.pivot('country','date','people_vaccinated')
# Out:
# date           2020-12-08  2020-12-09  2020-12-10  2020-12-11  2020-12-12  \
# country
# Albania               NaN         NaN         NaN         NaN         NaN
# Algeria               NaN         NaN         NaN         NaN         NaN
# Andorra               NaN         NaN         NaN         NaN         NaN
# Anguilla              NaN         NaN         NaN         NaN         NaN
# Argentina             NaN         NaN         NaN         NaN         NaN
# ...                   ...         ...         ...         ...         ...
# United States         NaN         NaN         NaN         NaN         NaN
# Uruguay               NaN         NaN         NaN         NaN         NaN
# Venezuela             NaN         NaN         NaN         NaN         NaN
# Wales                 NaN         NaN         NaN         NaN         NaN
# Zimbabwe              NaN         NaN         NaN         NaN         NaN
#
# ...

# %% [markdown]
# .crosstab(): Compute a simple cross tabulation of two (or more) factors. By default computes a frequency table of the factors unless an array of values and an aggregation function are passed.

# %%
pd.crosstab(covid.country, covid.people_vaccinated)
# Out:
# people_vaccinated  0.0         1.0         5.0         13.0        18.0        \
# country
# Albania                     1           0           0           0           0
# Andorra                     0           0           0           0           0
# Anguilla                    1           0           0           0           0
# Argentina                   0           0           0           0           0
# Australia                   7           0           0           0           0
# ...                       ...         ...         ...         ...         ...
# United States               0           0           0           0           0
# Uruguay                     0           0           0           0           0
# Venezuela                   1           0           0           0           0
# Wales                       0           0           0           0           0
# Zimbabwe                    1           0           0           0           0
#
# ...

# %% [markdown]
# .unique(): used to view all type of unique values in a certain column

# %%
# view all unique values of the country column
covid['country'].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Anguilla', 'Argentina',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bermuda', 'Bolivia',
#        'Brazil', 'Bulgaria', 'Cambodia', 'Canada', 'Cayman Islands',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czechia', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Estonia', 'Faeroe Islands',
#        'Falkland Islands', 'Finland', 'France', 'Germany', 'Gibraltar',
#        'Greece', 'Greenland', 'Guatemala', 'Guernsey', 'Guyana',
#        'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Ireland', 'Isle of Man', 'Israel', 'Italy',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kuwait', 'Latvia',
#        'Lebanon', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao',
#        'Malaysia', 'Maldives', 'Malta', 'Mauritius', 'Mexico', 'Monaco',
# ...

# %% [markdown]
# pd.isna(): detect missing values for an array like object

# %%
pd.isna(covid)
# Out:
#       country  iso_code   date  total_vaccinations  people_vaccinated  \
# 0       False     False  False               False              False
# 1       False     False  False                True               True
# 2       False     False  False               False              False
# 3       False     False  False               False              False
# 4       False     False  False               False              False
# ...       ...       ...    ...                 ...                ...
# 5231    False     False  False               False              False
# 5232    False     False  False               False              False
# 5233    False     False  False               False              False
# 5234    False     False  False               False              False
# 5235    False     False  False               False              False
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# pd.to_numeric(): converts the whole database or sectioned database to a numeric value

# %%
pd.to_numeric(covid.people_vaccinated)
